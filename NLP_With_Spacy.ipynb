# %% [markdown]
# <a href="https://colab.research.google.com/github/ghostriley08/NLP/blob/main/NLP_With_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
from datasets import load_dataset, disable_progress_bar
from datasets import logging as ds_logging
warnings.filterwarnings("ignore")
ds_logging.set_verbosity_error()
disable_progress_bar()

# %%
pip install spacy

# %%
# Introduction to NLP and spaCy
import spacy
nlp = spacy.load('en_core_web_sm') # Model converts text into doc to store processed text
doc = nlp("Apple is looking at buying U.K. startup for $1 billion") # doc object
print([token.text for token in doc]) # Square brackets `[]` instantly build and store the entire list in memory (eager evaluation),
#while omitting them creates a memory-saving generator that processes items one at a time (lazy evaluation).
# Tokenization using imdb dataset
from datasets import load_dataset

dataset = load_dataset("imdb")
text = dataset['train']['text'][0]
document = nlp(text)
first_text_tokens = [token.text for token in document]
print("First text tokens:\n", first_text_tokens, "\n")
# Out:
# ['Apple', 'is', 'looking', 'at', 'buying', 'U.K.', 'startup', 'for', '$', '1', 'billion']
# First text tokens:
# ...
